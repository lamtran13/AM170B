# %% [markdown]
# ### California: time-series Tree Coverage Loss heat map of county over the year

# %%
import pandas as pd
import plotly.figure_factory as ff
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('California_official.csv')
display(data)
# Out:
#       County  Date  Tree Coverage Loss  Avg Temp  Avg Precipitation  Ozone  \
# 0    Alameda  2001                60.0      59.6              22.27  0.087
# 1    Alameda  2002                15.0      59.0              18.34  0.106
# 2    Alameda  2003                62.0      59.7              16.43  0.094
# 3    Alameda  2004                69.0      59.6              18.35  0.080
# 4    Alameda  2005                36.0      59.4              24.52  0.090
# ..       ...   ...                 ...       ...                ...    ...
# 455     Yolo  2016               279.0      63.1              22.92  0.072
# 456     Yolo  2017                58.0      63.1              30.74  0.071
# 457     Yolo  2018              3230.0      62.4              17.84  0.080
# 458     Yolo  2019               400.0      62.4              33.14  0.066
# 459     Yolo  2020              1250.0      63.9               6.36  0.068
#
#      Nitrogen Dioxide  Floods  Wildfire
# ...

# %%
data1 = data.copy()
# data1 = data1.drop(columns=['tree'])
data1.drop(data1.iloc[:, 3:9], inplace=True, axis=1)
tree = data1
display(tree)
# Out:
#       County  Date  Tree Coverage Loss
# 0    Alameda  2001                60.0
# 1    Alameda  2002                15.0
# 2    Alameda  2003                62.0
# 3    Alameda  2004                69.0
# 4    Alameda  2005                36.0
# ..       ...   ...                 ...
# 455     Yolo  2016               279.0
# 456     Yolo  2017                58.0
# 457     Yolo  2018              3230.0
# 458     Yolo  2019               400.0
# 459     Yolo  2020              1250.0
#
# [460 rows x 3 columns]

# %%
#filter 2001
year_2001 = tree.loc[(tree['Date'] == 2001)]
year_2001 = year_2001.reset_index()
year_2001 = year_2001.drop(columns=['index'])
county = year_2001.iloc[:,0]
tree_2001 = year_2001.iloc[:,2]
#filter 2002
year_2002 = tree.loc[(tree['Date'] == 2002)]
year_2002 = year_2002.reset_index()
year_2002 = year_2002.drop(columns=['index'])
county = year_2001.iloc[:,0]
tree_2002 = year_2002.iloc[:,2]

#filter 2003
year_2003 = tree.loc[(tree['Date'] == 2003)]
year_2003 = year_2003.reset_index()
year_2003 = year_2003.drop(columns=['index'])
county = year_2003.iloc[:,0]
tree_2003 = year_2003.iloc[:,2]

#filter 2004
year_2004 = tree.loc[(tree['Date'] == 2004)]
year_2004 = year_2004.reset_index()
year_2004 = year_2004.drop(columns=['index'])
county = year_2004.iloc[:,0]
tree_2004 = year_2004.iloc[:,2]

#filter 2005
year_2005 = tree.loc[(tree['Date'] == 2005)]
year_2005 = year_2005.reset_index()
year_2005 = year_2005.drop(columns=['index'])
county = year_2005.iloc[:,0]
tree_2005 = year_2005.iloc[:,2]

#filter 2006
year_2006 = tree.loc[(tree['Date'] == 2006)]
year_2006 = year_2006.reset_index()
year_2006 = year_2006.drop(columns=['index'])
county = year_2006.iloc[:,0]
tree_2006 = year_2006.iloc[:,2]

#filter 2007
year_2007 = tree.loc[(tree['Date'] == 2007)]
year_2007 = year_2007.reset_index()
year_2007 = year_2007.drop(columns=['index'])
county = year_2007.iloc[:,0]
tree_2007 = year_2007.iloc[:,2]

#filter 2008
year_2008 = tree.loc[(tree['Date'] == 2008)]
year_2008 = year_2008.reset_index()
year_2008 = year_2008.drop(columns=['index'])
county = year_2008.iloc[:,0]
tree_2008 = year_2008.iloc[:,2]

#filter 2009
year_2009 = tree.loc[(tree['Date'] == 2009)]
year_2009 = year_2009.reset_index()
year_2009 = year_2009.drop(columns=['index'])
county = year_2009.iloc[:,0]
tree_2009 = year_2009.iloc[:,2]

#filter 2010
year_2010 = tree.loc[(tree['Date'] == 2010)]
year_2010 = year_2010.reset_index()
year_2010 = year_2010.drop(columns=['index'])
county = year_2010.iloc[:,0]
tree_2010 = year_2010.iloc[:,2]

#filter 2011
year_2011 = tree.loc[(tree['Date'] == 2011)]
year_2011 = year_2011.reset_index()
year_2011 = year_2011.drop(columns=['index'])
county = year_2011.iloc[:,0]
tree_2011 = year_2011.iloc[:,2]

#filter 2012
year_2012 = tree.loc[(tree['Date'] == 2012)]
year_2012 = year_2012.reset_index()
year_2012 = year_2012.drop(columns=['index'])
county = year_2012.iloc[:,0]
tree_2012 = year_2012.iloc[:,2]

#filter 2013
year_2013 = tree.loc[(tree['Date'] == 2013)]
year_2013 = year_2013.reset_index()
year_2013 = year_2013.drop(columns=['index'])
county = year_2013.iloc[:,0]
tree_2013 = year_2013.iloc[:,2]

#filter 2014
year_2014 = tree.loc[(tree['Date'] == 2014)]
year_2014 = year_2014.reset_index()
year_2014 = year_2014.drop(columns=['index'])
county = year_2014.iloc[:,0]
tree_2014 = year_2014.iloc[:,2]

#filter 2015
year_2015 = tree.loc[(tree['Date'] == 2015)]
year_2015 = year_2015.reset_index()
year_2015 = year_2015.drop(columns=['index'])
county = year_2015.iloc[:,0]
tree_2015 = year_2015.iloc[:,2]

#filter 2016
year_2016 = tree.loc[(tree['Date'] == 2016)]
year_2016 = year_2016.reset_index()
year_2016 = year_2016.drop(columns=['index'])
county = year_2016.iloc[:,0]
tree_2016 = year_2016.iloc[:,2]

#filter 2017
year_2017 = tree.loc[(tree['Date'] == 2017)]
year_2017 = year_2017.reset_index()
year_2017 = year_2017.drop(columns=['index'])
county = year_2017.iloc[:,0]
tree_2017 = year_2017.iloc[:,2]

#filter 2018
year_2018 = tree.loc[(tree['Date'] == 2018)]
year_2018 = year_2018.reset_index()
year_2018 = year_2018.drop(columns=['index'])
county = year_2018.iloc[:,0]
tree_2018 = year_2018.iloc[:,2]

#filter 2019
year_2019 = tree.loc[(tree['Date'] == 2019)]
year_2019 = year_2019.reset_index()
year_2019 = year_2019.drop(columns=['index'])
county = year_2019.iloc[:,0]
tree_2019 = year_2019.iloc[:,2]

#filter 2020
year_2020 = tree.loc[(tree['Date'] == 2020)]
year_2020 = year_2020.reset_index()
year_2020 = year_2020.drop(columns=['index'])
tree_2020 = year_2020.iloc[:,2]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

county = ['Alameda', 'Contra Costa', 'Fresno', 'Marin', 'Merced', 'Monterey', 'Orange', 'Riverside', 'San Joaquin',
         'San Luis Obispo', 'San Mateo', 'Santa Clara', 'Sonoma', 'Stanislaus', 'Sutter', 'Imperial', 'Los Angeles',
         'Sacramento', 'San Diego', 'San Francisco', 'Santa Barbara', 'Ventura', 'Yolo']
years = [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
        2016, 2017, 2018, 2019, 2020]  # Replace with your desired years
treeitation_data = [ tree_2001, tree_2002, tree_2003, tree_2004, tree_2005,
                     tree_2006, tree_2007, tree_2008, tree_2009, tree_2010,
                     tree_2011, tree_2012, tree_2013, tree_2014, tree_2015,
                     tree_2016, tree_2017, tree_2018, tree_2019, tree_2020] 
sns.set()
plt.figure(figsize=(30, 20)) 
heatmap = sns.heatmap(treeitation_data, cmap='YlGnBu', annot=True, fmt=".0f", xticklabels=county, yticklabels=years)

plt.xticks(fontsize=20, rotation=45)  
plt.yticks(fontsize=20, rotation=1)

plt.xlabel('County', fontsize=20)
plt.ylabel('Year', fontsize=20)

plt.show()
